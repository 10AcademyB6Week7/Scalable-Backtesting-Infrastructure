# %%
import pandas as pd
import numpy as np
import os,sys
# %matplotlib inline

# %%
sys.path.append(os.path.abspath(os.path.join('../scripts')))
from plot import Plots as plot

# %%
df = pd.read_csv("../data/Binance_BTCUSDT_d.csv",parse_dates=["date"])

# %%
df.shape
# Out:
# (1882, 10)

# %%
df.head()
# Out:
#            unix       date    symbol      open      high       low     close  \
# 0  1.665360e+12 2022-10-10  BTC/USDT  19439.96  19444.98  19407.83  19432.89
# 1  1.665274e+12 2022-10-09  BTC/USDT  19416.52  19558.00  19316.04  19439.02
# 2  1.665187e+12 2022-10-08  BTC/USDT  19530.09  19627.38  19237.14  19417.96
# 3  1.665101e+12 2022-10-07  BTC/USDT  19960.67  20068.82  19320.00  19530.09
# 4  1.665014e+12 2022-10-06  BTC/USDT  20158.26  20456.60  19853.00  19960.67
#
#      Volume BTC   Volume USDT  tradecount
# 0    1766.37089  3.431299e+07     44377.0
# 1  113900.82681  2.215007e+09   2833704.0
# 2  102480.09842  1.995917e+09   2637385.0
# 3  220874.83913  4.353681e+09   4324772.0
# 4  320122.17020  6.452892e+09   5085004.0

# %%
df['2020':'2022']
# Out:
#                     unix    symbol      open      high       low     close  \
# date
# 2022-10-10  1.665360e+12  BTC/USDT  19439.96  19444.98  19407.83  19432.89
# 2022-10-09  1.665274e+12  BTC/USDT  19416.52  19558.00  19316.04  19439.02
# 2022-10-08  1.665187e+12  BTC/USDT  19530.09  19627.38  19237.14  19417.96
# 2022-10-07  1.665101e+12  BTC/USDT  19960.67  20068.82  19320.00  19530.09
# 2022-10-06  1.665014e+12  BTC/USDT  20158.26  20456.60  19853.00  19960.67
# ...                  ...       ...       ...       ...       ...       ...
# 2020-01-05  1.578182e+12  BTC/USDT   7354.19   7495.00   7318.00   7358.75
# 2020-01-04  1.578096e+12  BTC/USDT   7345.00   7404.00   7272.21   7354.11
# 2020-01-03  1.578010e+12  BTC/USDT   6965.49   7405.00   6871.04   7344.96
# 2020-01-02  1.577923e+12  BTC/USDT   7200.77   7212.50   6924.74   6965.71
# 2020-01-01  1.577837e+12  BTC/USDT   7195.24   7255.00   7175.15   7200.85
#
#                Volume BTC   Volume USDT  tradecount
# date
# ...

# %%
df.nunique()
# Out:
# unix           1882
# date           1881
# symbol            1
# open           1880
# high           1828
# low            1827
# close          1880
# Volume BTC     1882
# Volume USDT    1882
# tradecount     1756
# dtype: int64

# %%
df.drop(columns=["unix","symbol"],inplace=True)

# %%
df.dtypes
# Out:
# unix                  float64
# date           datetime64[ns]
# symbol                 object
# open                  float64
# high                  float64
# low                   float64
# close                 float64
# Volume BTC            float64
# Volume USDT           float64
# tradecount            float64
# dtype: object

# %%
plot.plot_hist_all(df=df)

# %%
plot.plot_subplots(df['open'], df['close'], 'Opening Price Distribution', 'Closing Price Distribution')

# %%
a = df["2020":"2022"]

# %%
a
# Out:
#                 open      high       low     close     Volume BTC  \
# date
# 2022-10-10  19439.96  19444.98  19407.83  19432.89    1766.370890
# 2022-10-09  19416.52  19558.00  19316.04  19439.02  113900.826810
# 2022-10-08  19530.09  19627.38  19237.14  19417.96  102480.098420
# 2022-10-07  19960.67  20068.82  19320.00  19530.09  220874.839130
# 2022-10-06  20158.26  20456.60  19853.00  19960.67  320122.170200
# ...              ...       ...       ...       ...            ...
# 2020-01-05   7354.19   7495.00   7318.00   7358.75   38331.085604
# 2020-01-04   7345.00   7404.00   7272.21   7354.11   29987.974977
# 2020-01-03   6965.49   7405.00   6871.04   7344.96   68428.500451
# 2020-01-02   7200.77   7212.50   6924.74   6965.71   31951.483932
# 2020-01-01   7195.24   7255.00   7175.15   7200.85   16792.388165
#
#              Volume USDT  tradecount       Year
# date
# 2022-10-10  3.431299e+07     44377.0 2022-10-10
# 2022-10-09  2.215007e+09   2833704.0 2022-10-10
# ...

# %%
df[df.date =="2017-12-18"]
# Out:
#               unix       date    symbol      open     high       low  \
# 1757  1.513555e+12 2017-12-18  BTC/USDT  18860.04  19300.0  17029.98
# 1758  1.513555e+09 2017-12-18  BTC/USDT  18860.02  19300.0  17029.98
#
#          close    Volume BTC   Volume USDT  tradecount
# 1757  18856.25  10624.633071  1.963392e+08     91956.0
# 1758  18856.25  10280.980000  1.900573e+08         NaN

# %%
df["year"] = df.date.dt.to_period('Y')

# %%
df
# Out:
#               unix       date    symbol      open      high       low  \
# 0     1.665360e+12 2022-10-10  BTC/USDT  19439.96  19444.98  19407.83
# 1     1.665274e+12 2022-10-09  BTC/USDT  19416.52  19558.00  19316.04
# 2     1.665187e+12 2022-10-08  BTC/USDT  19530.09  19627.38  19237.14
# 3     1.665101e+12 2022-10-07  BTC/USDT  19960.67  20068.82  19320.00
# 4     1.665014e+12 2022-10-06  BTC/USDT  20158.26  20456.60  19853.00
# ...            ...        ...       ...       ...       ...       ...
# 1877  1.503274e+09 2017-08-21  BTC/USDT   4086.29   4119.62   3911.79
# 1878  1.503187e+09 2017-08-20  BTC/USDT   4139.98   4211.08   4032.62
# 1879  1.503101e+09 2017-08-19  BTC/USDT   4108.37   4184.69   3850.00
# 1880  1.503014e+09 2017-08-18  BTC/USDT   4285.08   4371.52   3938.77
# 1881  1.502928e+09 2017-08-17  BTC/USDT   4469.93   4485.39   4200.74
#
#          close    Volume BTC   Volume USDT  tradecount  year
# 0     19432.89    1766.37089  3.431299e+07     44377.0  2022
# ...

# %%
df_year = df.groupby("year").agg(open=("open", np.mean),close=("close", np.mean),high=("high","max"),low=("low","min"),Volume_BTC =("Volume BTC","sum"), Volume_USDT=("Volume USDT","sum"), tradecount = ("tradecount","sum"))

# %%
df_year.reset_index(inplace=True)

# %%
df_year.columns
# Out:
# Index(['year', 'open', 'close', 'high', 'low', 'Volume_BTC', 'Volume_USDT',
#        'tradecount'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1882 entries, 0 to 1881
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   unix         1882 non-null   float64
#  1   date         1882 non-null   datetime64[ns]
#  2   symbol       1882 non-null   object
#  3   open         1882 non-null   float64
#  4   high         1882 non-null   float64
#  5   low          1882 non-null   float64
#  6   close        1882 non-null   float64
#  7   Volume BTC   1882 non-null   float64
#  8   Volume USDT  1882 non-null   float64
#  9   tradecount   1758 non-null   float64
# dtypes: datetime64[ns](1), float64(8), object(1)
# memory usage: 147.2+ KB

# %%
plot.plot_bar(df=df_year,x_col = "year",y_col="Volume_USDT",title="Total Volume USDT distribution",xlabel="Year",ylabel="USDT Volume")

# %%
df_2021 = df[""]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/issue/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/issue/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/issue/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2021'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_2021
# Out:
#              unix       date    symbol      open     high       low     close  \
# 647  1.609459e+12 2021-01-01  BTC/USDT  28923.63  29600.0  28624.57  29331.69
#
#        Volume BTC   Volume USDT  tradecount  year
# 647  54182.925011  1.582527e+09   1314910.0  2021

# %%
df_year = df["2022"].groupby("year").agg(open=("open", np.mean),close=("close", np.mean),high=("high","max"),low=("low","min"),Volume_BTC =("Volume BTC","sum"), Volume_USDT=("Volume USDT","sum"), tradecount = ("tradecount","sum"))
